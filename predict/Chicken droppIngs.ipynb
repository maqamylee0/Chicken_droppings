# %%
print(4)
# Out:
# 4

# %%
import numpy as np

# %%
import tensorflow as tf

# %%
filename = 'pupu.jpg'

# %% [markdown]
# # First method to load image with IPython.display

# %%
from IPython.display import Image

# %%
Image(filename = 'pupu.jpg',width=224,height=224)

# %% [markdown]
# # Second method to load an image with Tensorflow keras and matplotlib

# %%
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img(filename,target_size =(224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# # Third method to load an image with opencv

# %%
import cv2

# %%
imgg=cv2.imread(filename)

# %%
imgg=cv2.resize(imgg,(224,224))

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg,cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Fourth method to load image using Python Imaging Library

# %%
from PIL import Image

# %%
im = Image.open(filename)

# %%
im = im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# # Loading the learning model that is pretrained

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17235968/17225924 [==============================] - 437s 25us/step

# %% [markdown]
# # Preprocessing the image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename,target_size =(224,224))
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_img = np.expand_dims(resized_img,axis = 0)
final_img = tf.keras.applications.mobilenet.preprocess_input(final_img)
#plt.imshow(final_img)
final_img.shape
# Out:
# (1, 224, 224, 3)

# %%
prediction = mobile.predict(final_img)

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(prediction)
# Out:
# ...
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# ~/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ...

# %%
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-7c99561e17b8> in <module>
# ----> 1 print(results)
#
# NameError: name 'results' is not defined
